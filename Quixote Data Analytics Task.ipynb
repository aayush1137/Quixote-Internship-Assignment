# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
#importing Data
working_directory = os.getcwd()
working_directory
filename = "/Users/aayushsharma/_Data Analytics  -Indian Stock Market Top 2000.csv"
filename
# Out:
# '/Users/aayushsharma/_Data Analytics  -Indian Stock Market Top 2000.csv'

# %%
df = pd.read_csv(filename)

# %%
df.columns
# Out:
# Index(['Name', 'Ticker', 'Sub-Sector', 'Market Cap', 'Close Price', 'PE Ratio',
#        'Return on Equity', 'Return on Assets', 'Net Profit Margin',
#        '5Y Avg EBITDA Margin', 'EBITDA Margin', '1Y Return vs Nifty',
#        '5Y CAGR', 'Net Income / Liabilities', '5Y Historical Revenue Growth',
#        '5Y Historical EBITDA Growth', '5Y Historical EPS Growth',
#        'Forward PE Ratio', 'Enterprise Value', 'PB Ratio', 'Dividend Yield',
#        'PE Premium vs Sector', 'Domestic Institutional Holding',
#        'Mutual Fund Holding', 'Promoter Holding',
#        'Foreign Institutional Holding', 'Retail Investor Holding',
#        'Pledged Promoter Holdings', 'Insurance Firms Holding',
#        'No. of Shareholders', 'Total Revenue', 'Net Income', 'PBT',
#        'Earnings Per Share', 'EBITDA', 'Long Term Investments',
#        'Reserves & Surplus', 'Cash and Equivalent', 'Book Value',
#        'Free Cash Flow', 'Operating Cash Flow'],
#       dtype='object')

# %%
df.rename(columns={'Column1': 'Name'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b7b9b0df046b> in <module>
#       1 counts_subsector=df.rename(columns={'Column1': 'Name'}, inplace=True)
# ----> 2 counts_subsector.to_csv('Quixote_SubSector_count.csv', index=false)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
#Plot for Task 1
ax = df['Sub-Sector'].value_counts().plot.bar(figsize=(29,5))
ax.set_ylabel("No. of comapnies")
# Out:
# Text(0, 0.5, 'No. of comapnies')

# %%
df['Market Cap'].max()
# Out:
# 1679534.21004169

# %%
bins = [0,5000,20000,2000000]
labels = ['Small Cap', 'Mid Cap', 'Large Cap']

# %%
df['marketcap_category'] = pd.cut(df['Market Cap'],bins,labels=labels)

# %%
df.head()
# Out:
#                         Name     Ticker                Sub-Sector  \
# 0             20 Microns Ltd  20MICRONS       Specialty Chemicals
# 1            3i Infotech Ltd  3IINFOLTD  IT Services & Consulting
# 2               3M India Ltd    3MINDIA                Stationery
# 3         5Paisa Capital Ltd     5PAISA    Diversified Financials
# 4  63 Moons Technologies Ltd    63MOONS  IT Services & Consulting
#
#      Market Cap  Close Price    PE Ratio   Return on Equity  Return on Assets  \
# 0    264.295900        77.70   11.506134   11.3774827876566  5.12986577930634
# 1    950.147070        54.55    2.429050   39.3681530200937  25.9530183753156
# 2  22560.274062     19802.90  138.926498   8.87083778313726  6.46599865814301
# 3   1098.001394       367.85   74.795735    9.9751979071111  1.96990130365063
# 4   1061.649492       219.60  -16.734702  -2.05046987241126  -1.8808991195886
#
#    Net Profit Margin  5Y Avg EBITDA Margin  ...                PBT  \
# ...

# %%
#Plot for Task 2
ax = df['marketcap_category'].value_counts().plot.bar(figsize=(29,5))
ax.set_ylabel("No. of comapnies")
# Out:
# Text(0, 0.5, 'No. of comapnies')

# %%
df_intr_val.drop('index', axis = 1, inplace=True)

# %%
df_intr_val['Earnings Per Share']=pd.to_numeric(df_intr_val['Earnings Per Share'])

# %%
columns = {df_intr_val.columns[1]:'Ticker', df_intr_val.columns[2]:'Market_Cap'}
df_intr_val.rename(columns=columns, inplace = True)

# %%
df_intr_val
# Out:
#        Ticker   Market_Cap  Earnings Per Share    5Y CAGR  Dividend Yield  \
# 0        RVNL  7203.744100            4.423986  26.389795        4.573083
# 1  MAHESHWARI   232.929964            3.138810  -2.321231        0.635324
# 2   THYROCARE  4127.754078           21.408765   1.779773        3.202188
# 3     EQUITAS  3730.639105           13.845929  -7.663355        2.748510
# 4  VLSFINANCE   641.016242           57.064413  21.631833        0.907565
# 5  VSTTILLERS  2183.251923          105.063610   6.645828        0.791437
# 6    HBLPOWER  1785.135452            0.494959   9.787062        0.543478
# 7  KARURVYSYA  3747.746804            4.496318 -13.641620        1.066402
# 8    ADFFOODS  1449.244401           24.091261  34.496804        0.430141
# 9    ADCINDIA   142.439000            7.891304   4.267034        0.807363
#
#    intrinsic_Value_bad  intrinsic_Value_good  intrinsic_Value_best
# 0            48.756805             51.078557             52.239434
# ...

# %%
#Column

for ticker in df_intr_val:
    df_intr_val['intrinsic_Value_bad'] = (df_intr_val['Earnings Per Share']*(8.5+2*-0.05)*6)/df_intr_val['Dividend Yield']
    df_intr_val['intrinsic_Value_good'] = (df_intr_val['Earnings Per Share']*(8.5+2*0.15)*6)/df_intr_val['Dividend Yield']
    df_intr_val['intrinsic_Value_best'] = (df_intr_val['Earnings Per Share']*(8.5+2*0.25)*6)/df_intr_val['Dividend Yield']

# %%
# df_intr_val.plot.line(x=['intrinsic_Value_bad','intrinsic_Value_good','intrinsic_Value_best'], y='Market Cap')
# plt.plot(x='Ticker', y='intrinsic_value_bad')
from matplotlib import rcParams
rcParams['figure.figsize'] = 10,6
x =

# %%
import seaborn as sns
sns.lineplot(x =df_intr_val.intrinsic_Value_bad,y= df_intr_val.Market_Cap)
# Out:
# <AxesSubplot:xlabel='intrinsic_Value_bad', ylabel='Market_Cap'>

# %%
df_intr_val.to_csv('Quixote_intrinsic_value.csv')
